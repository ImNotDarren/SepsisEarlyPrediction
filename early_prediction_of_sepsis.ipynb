# %%
import pandas as pd
import os

# %%
df = pd.read_csv('dataset/training_setA/p008292.psv', sep='|')

# %%
df
# Out:
#        HR  O2Sat   Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0     NaN    NaN    NaN    NaN    NaN  NaN   NaN    NaN         NaN   NaN
# 1   106.0   95.5    NaN   91.0  69.67  NaN  18.5    NaN         NaN   NaN
# 2   101.0   95.5    NaN   90.0  60.33  NaN  19.5    NaN         NaN   NaN
# 3   107.0   95.0    NaN   87.0  61.67  NaN  20.0    NaN         NaN   NaN
# 4   106.0   97.0    NaN   84.0  54.67  NaN  21.0    NaN         NaN   NaN
# 5   105.0   98.0    NaN   88.5  57.83  NaN  22.0    NaN         NaN   NaN
# 6   105.0   98.0    NaN   76.0  56.67  NaN  22.0    NaN         NaN   NaN
# 7   104.0   99.0  36.22   83.0  64.33  NaN  18.0    NaN         NaN   NaN
# 8   106.0   99.0    NaN   87.0  59.67  NaN  17.0    NaN         NaN   NaN
# 9   107.0   98.0    NaN   92.0  65.33  NaN  21.0    NaN         NaN   NaN
# 10  105.0   98.0    NaN   87.0  61.00  NaN  17.0    NaN         NaN   NaN
# 11  106.0   99.0  36.72   90.0  60.67  NaN  18.0    NaN         NaN   NaN
# ...
